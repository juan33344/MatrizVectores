# %% [markdown]
# ## Impoetacion de archgivos desde csv en pandas

# %%
import pandas as pd

# %%
DatoUnivercidad = pd.read_csv('ModalidadVirtual.csv')

# %%
DatoUnivercidad
# Out:
#      Unnamed: 0        time                       carrera acepta  \
# 0             0  2020-11-08        Ingeniería de Sistemas     Si
# 1             1  2020-11-08                    Psicología     Si
# 2             2  2020-11-08        Ingeniería de Sistemas     Si
# 3             3  2020-11-08        Ingeniería de Sistemas     Si
# 4             4  2020-11-08        Ingeniería de Sistemas     Si
# ..          ...         ...                           ...    ...
# 217         230  2020-12-10  Gestión Turística y Hotelera     Si
# 218         231  2020-12-11        Ingeniería de Sistemas     No
# 219         232  2020-12-11  Gestión Turística y Hotelera     No
# 220         233  2020-12-11         Ingeniería Agronómica     Si
# 221         234  2020-12-12        Comercio Internacional     Si
#
#                           positivo  \
# 0                Horario flexible.
# 1    Acceso desde cualquier lugar.
# 2                Horario flexible.
# 3                Horario flexible.
# ...

# %% [markdown]
# Visualizar datos por columnas

# %%
DatoUnivercidad['carrera']
# Out:
# 0            Ingeniería de Sistemas
# 1                        Psicología
# 2            Ingeniería de Sistemas
# 3            Ingeniería de Sistemas
# 4            Ingeniería de Sistemas
#                    ...
# 217    Gestión Turística y Hotelera
# 218          Ingeniería de Sistemas
# 219    Gestión Turística y Hotelera
# 220           Ingeniería Agronómica
# 221          Comercio Internacional
# Name: carrera, Length: 222, dtype: object

# %% [markdown]
# Visualizar los datos de las edades mayores a 23 años

# %%
DatoUnivercidad[DatoUnivercidad['edad'] > 23]
# Out:
#      Unnamed: 0        time                       carrera acepta  \
# 1             1  2020-11-08                    Psicología     Si
# 4             4  2020-11-08        Ingeniería de Sistemas     Si
# 5             5  2020-11-08      Ciencias de la Educación     Si
# 9             9  2020-11-08        Ingeniería de Sistemas     Si
# 10           10  2020-11-08                    Psicología     Si
# ..          ...         ...                           ...    ...
# 211         223  2020-12-08         Ingeniería Agronómica     Si
# 212         224  2020-12-08                       Derecho     Si
# 213         226  2020-12-09      Ciencias de la Educación     Si
# 216         229  2020-12-10                Trabajo Social     Si
# 219         232  2020-12-11  Gestión Turística y Hotelera     No
#
#                           positivo  \
# 1    Acceso desde cualquier lugar.
# 4    Acceso desde cualquier lugar.
# 5    Acceso desde cualquier lugar.
# 9                Horario flexible.
# ...

# %%
DatoUnivercidad.head()
# Out:
#    Unnamed: 0        time                 carrera acepta  \
# 0           0  2020-11-08  Ingeniería de Sistemas     Si
# 1           1  2020-11-08              Psicología     Si
# 2           2  2020-11-08  Ingeniería de Sistemas     Si
# 3           3  2020-11-08  Ingeniería de Sistemas     Si
# 4           4  2020-11-08  Ingeniería de Sistemas     Si
#
#                         positivo  \
# 0              Horario flexible.
# 1  Acceso desde cualquier lugar.
# 2              Horario flexible.
# 3              Horario flexible.
# 4  Acceso desde cualquier lugar.
#
#                                             negativo  edad    sexo   trabajo
# 0             Contacto Personal Docente-Estudiantil.    20  Hombre  Eventual
# 1             Contacto Personal Docente-Estudiantil.    26  Hombre  Eventual
# 2  Falta de recursos de calidad(plataformas, doce...    20   Mujer        Sí
# 3                               Conexión a internet.    18   Mujer        No
# ...

# %%
DatoUnivercidad.shift()
# Out:
#      Unnamed: 0        time                       carrera acepta  \
# 0           NaN        None                          None   None
# 1           0.0  2020-11-08        Ingeniería de Sistemas     Si
# 2           1.0  2020-11-08                    Psicología     Si
# 3           2.0  2020-11-08        Ingeniería de Sistemas     Si
# 4           3.0  2020-11-08        Ingeniería de Sistemas     Si
# ..          ...         ...                           ...    ...
# 217       229.0  2020-12-10                Trabajo Social     Si
# 218       230.0  2020-12-10  Gestión Turística y Hotelera     Si
# 219       231.0  2020-12-11        Ingeniería de Sistemas     No
# 220       232.0  2020-12-11  Gestión Turística y Hotelera     No
# 221       233.0  2020-12-11         Ingeniería Agronómica     Si
#
#                           positivo  \
# 0                             None
# 1                Horario flexible.
# 2    Acceso desde cualquier lugar.
# 3                Horario flexible.
# ...

# %%
DatoUnivercidad.tail()
# Out:
#      Unnamed: 0        time                       carrera acepta  \
# 217         230  2020-12-10  Gestión Turística y Hotelera     Si
# 218         231  2020-12-11        Ingeniería de Sistemas     No
# 219         232  2020-12-11  Gestión Turística y Hotelera     No
# 220         233  2020-12-11         Ingeniería Agronómica     Si
# 221         234  2020-12-12        Comercio Internacional     Si
#
#                           positivo  \
# 217              Horario flexible.
# 218  Acceso desde cualquier lugar.
# 219              Horario flexible.
# 220  Acceso desde cualquier lugar.
# 221              Horario flexible.
#
#                                               negativo  edad    sexo trabajo
# 217                               Conexión a internet.    19   Mujer      Sí
# 218  Falta de recursos de calidad(plataformas, doce...    23   Mujer      No
# 219  Falta de recursos de calidad(plataformas, doce...    25  Hombre      Sí
# ...

# %%
DatoUnivercidad.index
# Out:
# RangeIndex(start=0, stop=222, step=1)

# %%
DatoUnivercidad.dtypes
# Out:
# Unnamed: 0     int64
# time          object
# carrera       object
# acepta        object
# positivo      object
# negativo      object
# edad           int64
# sexo          object
# trabajo       object
# dtype: object

# %% [markdown]
# Buscar las carreras en puras mayusculas

# %%
DatoUnivercidad.loc[:,'carrera'].str.upper()
# Out:
# 0            INGENIERÍA DE SISTEMAS
# 1                        PSICOLOGÍA
# 2            INGENIERÍA DE SISTEMAS
# 3            INGENIERÍA DE SISTEMAS
# 4            INGENIERÍA DE SISTEMAS
#                    ...
# 217    GESTIÓN TURÍSTICA Y HOTELERA
# 218          INGENIERÍA DE SISTEMAS
# 219    GESTIÓN TURÍSTICA Y HOTELERA
# 220           INGENIERÍA AGRONÓMICA
# 221          COMERCIO INTERNACIONAL
# Name: carrera, Length: 222, dtype: object
